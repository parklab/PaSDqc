# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

import PaSDqc

# %matplotlib inline

# %%
sample_good = PSDTools.SamplePSD(pd.read_table("/home/mas138/orchestra/data/BSM/Cell/1465/MDAqc/1x/psd/1465-cortex_1-neuron_MDA_30.1x.chroms.spec", index_col=0), name='Good')
sample_malbac = PSDTools.SamplePSD(pd.read_table("/home/mas138/orchestra/data/BSM/Cell/MALBAC/MDAqc/1x/psd/MALBAC_single-cell_SRX204745.sorted.1x.chroms.spec", index_col=0), name='Good')
sample_bulk = PSDTools.SamplePSD(pd.read_table("/home/mas138/orchestra/data/BSM/Cell/1465/MDAqc/1x/psd/1465-cortex_BulkDNA_WGSb.1x.chroms.spec.skip", index_col=0), name='Bulk')
norm = pd.Series.from_csv("/home/mas138/sandbox/dev/MDAqc/db/bulk_1x.smooth3.spec", index_col=0, sep="\t").as_matrix()

# %%
freq = np.array(sample_good.df.index.tolist())
avg_good = sample_good.avg_PSD()
avg_bulk = sample_bulk.avg_PSD()
avg_malbac = sample_malbac.avg_PSD()

# %%
df_naive = pd.read_table("naive_spectra.txt")

# %%
from src import extra_tools
freq, nd, sample_list = extra_tools.mk_ndarray("data/fig1/psd")

# %%
sns.set_context("poster")
sns.set_style("ticks", {'ytick.minor.size': 0.0, 'xtick.minor.size': 0.0})
fig = plt.figure(figsize=(10, 10))
ax0 = plt.subplot(212)
ax1 = plt.subplot(211)# , sharex=ax0)
# ax2 = plt.subplot(313)# , sharex=ax0)

ax0.plot(1/df_naive.freq, df_naive.psd_Bulk, label='Bulk')
ax0.plot(1/df_naive.freq, df_naive.psd_MDA, label='MDA')
ax0.plot((0,0), (0,0))
ax0.plot(1/df_naive.freq, df_naive.psd_MALBAC, label='MALBAC')
ax0.set_xscale('log')
ax0.set_xlim(1e2, 1e6)
ax0.set_ylim(-20, 35)
ax0.legend(loc=(0.01, 0.7))
ax0.set_xlabel('Genomic scale')
# ax0.set_xticklabels([])
ax0.set_ylabel('Power spectral density (dB)')

ax0.plot((92804, 92804), (-15, 30), 'k--', linewidth=2)
ax0.plot((5e3, 5e3), (-15, 30), 'k--', linewidth=2)
ax0.plot((1e3, 1e3), (-15, 30), 'k--', linewidth=2)
ax0.set_ylim(-20, 30)
ax0.set_xticklabels(["0", "100 bp", "1 kb", "10 kb", "100 kb", "1 mb"])

ax1.plot(1/freq, 10*np.log(avg_bulk), label='Bulk')
ax1.plot(1/freq, 10*np.log(avg_good/norm), label='MDA')
ax1.plot((0,0), (0,0))
ax1.plot(1/freq, 10*np.log(avg_malbac/norm), label='MALBAC')
ax1.set_xscale('log')
ax1.set_ylabel("Power Spectral Density (dB)")
# ax1.legend(loc=(1, 0.60))
# ax1.set_xticklabels([])
# ax1.set_xlabel("Genomic scale (bp)")

# Vertical lines
ax1.plot((92804, 92804), (-10, 50), 'k--', linewidth=2)
ax1.plot((5e3, 5e3), (-10, 50), 'k--', linewidth=2)
ax1.plot((1e3, 1e3), (-10, 50), 'k--', linewidth=2)
ax1.set_ylim(-15, 50)
ax1.legend(loc=(0.01, 0.6))
ax1.set_xticklabels(["0", "100 bp", "1 kb", "10 kb", "100 kb", "1 mb"])

# Labels
ax1.text(1.25e5, 45, "Supra-amplicon\n      variance", fontsize=16)
ax1.text(1.25e4, 45, "    MDA\n Amplicon\nsize range", fontsize=16)
ax1.text(1.25e3, 45, "  MALBAC\n  Amplicon\n size range", fontsize=16)
ax1.text(1.5e2, 45, "Paired-end\ncorrelation", fontsize=16)

# for avg, s, c in zip(nd[3:6], sample_list[3:6], sns.color_palette("Reds_r", 8)):
#     ax2.plot(1/freq, 10*np.log(avg/norm), label=s, color=c)

# for avg, s, c in zip(np.concatenate([nd[0:3], nd[6:]]), sample_list[0:3]+sample_list[6:], sns.color_palette("Greens_r", 8)):
#     ax2.plot(1/freq, 10*np.log(avg/norm), label=s, color=c)

# ax2.set_xscale('log')
# ax2.legend(loc=[1, 0])
# ax2.plot((92804, 92804), (-10, 70), 'k--', linewidth=2)
# ax2.plot((5e3, 5e3), (-10, 70), 'k--', linewidth=2)
# ax2.plot((1e3, 1e3), (-10, 70), 'k--', linewidth=2)
# ax2.set_ylim(-15, 70)
# ax2.text(1.06e3, 64, "      MDA\nsub-amplicon\n   variance", fontsize=16)

# ax2.set_ylabel("Power Spectral Density (dB)")
# ax2.set_xlabel('Genomic Scale (BP)')

plt.tight_layout()
sns.despine(fig=fig, ax=ax0)
sns.despine(fig=fig, ax=ax1)
# sns.despine(fig=fig, ax=ax2, offset=10, trim=True)

fig.text(0.01, 0.98, "A", weight="bold", horizontalalignment='left', verticalalignment='center', fontsize=20)
fig.text(0.01, 0.49, "B", weight="bold", horizontalalignment='left', verticalalignment='center', fontsize=20)
# fig.text(0.01, 0.35, "C", weight="bold", horizontalalignment='left', verticalalignment='center')

# %%
fig.savefig("figs/Fig2_06-26-2017.pdf")
fig.savefig("figs/Fig2_06-26-2017.png")
